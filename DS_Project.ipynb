# %%
import numpy as np
import seaborn as sns

# %%
import pandas as pd
df = pd.read_excel(r"S:\DATA SCIENCE\DS Project/Data.xlsx")
df.head(5)
# Out:
#    ID Are you still going to school?  \
# 0   1                            NaN
# 1   2                            NaN
# 2   3               No, I am at home
# 3   4               No, I am at home
# 4   5               No, I am at home
#
#   Do you have any other children living in your house with you?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#   How many people live in your home with you (including adults)?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                  5
# 3                                                  4
# 4                                                  5
#
#   What year are you in now? Gender  Year    Month  Day  \
# ...

# %%
df.describe()
# Out:
#                ID         Year         Day  \
# count  986.000000   986.000000  986.000000
# mean   493.500000  2009.879310   15.801217
# std    284.777984     1.122288    8.767791
# min      1.000000  2007.000000    1.000000
# 25%    247.250000  2009.000000    8.000000
# 50%    493.500000  2010.000000   16.000000
# 75%    739.750000  2011.000000   23.000000
# max    986.000000  2012.000000   31.000000
#
#        3. How many times did you brush your teeth YESTERDAY?  \
# count                                         986.000000
# mean                                            1.628803
# std                                             0.566530
# min                                             0.000000
# 25%                                             1.000000
# 50%                                             2.000000
# 75%                                             2.000000
# max                                             3.000000
#
# ...

# %% [markdown]
# # Renaming columns

# %%
df.rename(columns={'13. On a scale of 0 to 10 (0 being not very safe and 10 being very safe), how safe do you feel playing in your area?':'scale_0_to_10',
                 'Your Health ':'Your_Health',
                   'Your School':'Your_School','Your Family':'Your_Family',
                   'Your Friends':'Your_Friends','Your Appearance (how you look)':'Your_Appearance_how_you_look',
                   'Your Life':'Your_Life',
                   '3. How many times did you brush your teeth YESTERDAY?':'How_many_times_did_you_brush_your_teeth_YESTERDAY'}, inplace=True)

# %%
df.head(16)
# Out:
#     ID Are you still going to school?  \
# 0    1                            NaN
# 1    2                            NaN
# 2    3               No, I am at home
# 3    4               No, I am at home
# 4    5               No, I am at home
# 5    6               No, I am at home
# 6    7               No, I am at home
# 7    8               No, I am at home
# 8    9               No, I am at home
# 9   10               No, I am at home
# 10  11               No, I am at home
# 11  12               No, I am at home
# 12  13               No, I am at home
# 13  14               No, I am at home
# 14  15               No, I am at home
# 15  16               No, I am at home
#
#    Do you have any other children living in your house with you?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 Yes
# 3                                                 Yes
# ...

# %% [markdown]
# # Checking NaN values

# %%
df.isnull().sum()
# Out:
# ID                                                                                                                                                                                                                                                             0
# Are you still going to school?                                                                                                                                                                                                                                 2
# Do you have any other children living in your house with you?                                                                                                                                                                                                  2
# ...

# %% [markdown]
# # Removing strings and characters from the column

# %%
df['How many people live in your home with you (including adults)?'] = df['How many people live in your home with you (including adults)?']. replace('\+', '', regex=True)

# %%
df['How many people live in your home with you (including adults)?']=df['How many people live in your home with you (including adults)?'].astype('float')
df['How many people live in your home with you (including adults)?']
# Out:
# 0      NaN
# 1      NaN
# 2      5.0
# 3      4.0
# 4      5.0
#       ...
# 981    3.0
# 982    4.0
# 983    4.0
# 984    4.0
# 985    3.0
# Name: How many people live in your home with you (including adults)?, Length: 986, dtype: float64

# %% [markdown]
# # Mode imputatuion on the Data

# %%
from sklearn.impute import SimpleImputer

# %%
median_imputer = SimpleImputer(missing_values=np.nan, strategy='median')
df[["How many people live in your home with you (including adults)?","scale_0_to_10"]] = pd.DataFrame(median_imputer.fit_transform(df[["How many people live in your home with you (including adults)?","scale_0_to_10"]]))

df["How many people live in your home with you (including adults)?"].isna().sum()
# Out:
# 0

# %%
import re

# %%
mode_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df[["How many people live in your home with you (including adults)?",
"Are you still going to school?",
"Do you have any other children living in your house with you?",
"6. In the last 7 days, how many days did you do sports or exercise for at least 1 hour in total. This includes doing any activities (including online activities) or playing sports where your heart beat faster, you breathed faster and you felt warmer?",
"7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?",
"8. In the last 7 days, how many days did you feel tired?",
"9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?",
"10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?",
"11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?",
"12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?",
"14. From your house, can you easily walk to a park (for example a field or grassy area)?",
"15. From your house, can you easily walk to somewhere you can play?",
"16. Do you have a garden?",
"17. How often do you go out to play outside?",
"18. Do you have enough time for play?",
"19. What type of places do you play in?",
"20. Can you play in all the places you would like to?",
"21. Do you have somewhere at home where you have space to relax?",
"22. Tell us if you agree or disagree with the following: [I feel part of my school community]",
"25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)",
"26. Are you able to keep in touch with your friends?",
"27. If yes, how are you keeping in touch (tick all you use)?",
"2. Did you eat any fruit and vegetables YESTERDAY? "]] = pd.DataFrame(
mode_imputer.fit_transform(
df[["How many people live in your home with you (including adults)?",
"Are you still going to school?",
"Do you have any other children living in your house with you?",
"6. In the last 7 days, how many days did you do sports or exercise for at least 1 hour in total. This includes doing any activities (including online activities) or playing sports where your heart beat faster, you breathed faster and you felt warmer?",
"7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?",
"8. In the last 7 days, how many days did you feel tired?",
"9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?",
"10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?",
"11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?",
"12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?",
"14. From your house, can you easily walk to a park (for example a field or grassy area)?",
"15. From your house, can you easily walk to somewhere you can play?",
"16. Do you have a garden?",
"17. How often do you go out to play outside?",
"18. Do you have enough time for play?",
"19. What type of places do you play in?",
"20. Can you play in all the places you would like to?",
"21. Do you have somewhere at home where you have space to relax?",
"22. Tell us if you agree or disagree with the following: [I feel part of my school community]",
"25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)",
"26. Are you able to keep in touch with your friends?",
"27. If yes, how are you keeping in touch (tick all you use)?",
"2. Did you eat any fruit and vegetables YESTERDAY? "]]))

# %%
df.rename(columns={'6. In the last 7 days, how many days did you do sports or exercise for at least 1 hour in total. This includes doing any activities (including online activities) or playing sports where your heart beat faster, you breathed faster and you felt warmer?': 'Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer','16. Do you have a garden?': 'Q16_Do_you_have_a_garden', '26. Are you able to keep in touch with your friends?': 'Q26_Are_you_able_to_keep_in_touch_with_your_friends'}, inplace=True)

# %% [markdown]
# # Changing string values to numeric values

# %%
df["Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer"]
# Out:
# 0        7 days
# 1        7 days
# 2        7 days
# 3        7 days
# 4        7 days
#          ...
# 981    1-2 days
# 982    3-4 days
# 983    5-6 days
# 984      7 days
# 985    3-4 days
# Name: Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer, Length: 986, dtype: object

# %%
df["Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer"].replace("1-2 days", "1", regex=True, inplace=True)
df["Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer"].replace("0 days", "0", regex=True, inplace=True)
df["Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer"].replace("3-4 days", "3", regex=True, inplace=True)
df["Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer"].replace("5-6 days", "5", regex=True, inplace=True)
df["Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer"].replace("7 days", "7", regex=True, inplace=True)
df["Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer"]
# Out:
# 0      7
# 1      7
# 2      7
# 3      7
# 4      7
#       ..
# 981    1
# 982    3
# 983    5
# 984    7
# 985    3
# Name: Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer, Length: 986, dtype: object

# %%
df["7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?"].replace("1-2 days", "1", regex=True, inplace=True)
df["7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?"].replace("0 days", "0", regex=True, inplace=True)
df["7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?"].replace("3-4 days", "3", regex=True, inplace=True)
df["7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?"].replace("5-6 days", "5", regex=True, inplace=True)
df["7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?"].replace("7 days", "7", regex=True, inplace=True)
df["7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?"]
# Out:
# 0      7
# 1      7
# 2      7
# 3      1
# 4      1
#       ..
# 981    7
# 982    7
# 983    7
# 984    5
# 985    7
# Name: 7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?, Length: 986, dtype: object

# %%
df["8. In the last 7 days, how many days did you feel tired?"].replace("1-2 days", "1", regex=True, inplace=True)
df["8. In the last 7 days, how many days did you feel tired?"].replace("0 days", "0", regex=True, inplace=True)
df["8. In the last 7 days, how many days did you feel tired?"].replace("3-4 days", "3", regex=True, inplace=True)
df["8. In the last 7 days, how many days did you feel tired?"].replace("5-6 days", "5", regex=True, inplace=True)
df["8. In the last 7 days, how many days did you feel tired?"].replace("7 days", "7", regex=True, inplace=True)
df["8. In the last 7 days, how many days did you feel tired?"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      3
#       ..
# 981    1
# 982    3
# 983    3
# 984    0
# 985    0
# Name: 8. In the last 7 days, how many days did you feel tired?, Length: 986, dtype: object

# %%
df['9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?'].replace("1-2 days", "1", regex=True, inplace=True)
df['9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?'].replace("0 days", "0", regex=True, inplace=True)
df['9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?'].replace("3-4 days", "3", regex=True, inplace=True)
df['9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?'].replace("5-6 days", "5", regex=True, inplace=True)
df['9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?'].replace("7 days", "7", regex=True, inplace=True)
df['9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?']
# Out:
# 0      3
# 1      3
# 2      3
# 3      0
# 4      1
#       ..
# 981    0
# 982    0
# 983    3
# 984    5
# 985    1
# Name: 9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?, Length: 986, dtype: object

# %%
df['10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?'].replace("1-2 days", "1", regex=True, inplace=True)
df['10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?'].replace("0 days", "0", regex=True, inplace=True)
df['10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?'].replace("3-4 days", "3", regex=True, inplace=True)
df['10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?'].replace("5-6 days", "5", regex=True, inplace=True)
df['10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?'].replace("7 days", "7", regex=True, inplace=True)
df['10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 981    1
# 982    3
# 983    0
# 984    0
# 985    1
# Name: 10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?, Length: 986, dtype: object

# %%
df['11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?'].replace("1-2 days", "1", regex=True, inplace=True)
df['11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?'].replace("0 days", "0", regex=True, inplace=True)
df['11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?'].replace("3-4 days", "3", regex=True, inplace=True)
df['11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?'].replace("5-6 days", "5", regex=True, inplace=True)
df['11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?'].replace("7 days", "7", regex=True, inplace=True)
df['11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?']
# Out:
# 0      7
# 1      7
# 2      7
# 3      3
# 4      3
#       ..
# 981    5
# 982    1
# 983    7
# 984    3
# 985    7
# Name: 11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?, Length: 986, dtype: object

# %%
df['12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?'].replace("1-2 days", "1", regex=True, inplace=True)
df['12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?'].replace("0 days", "0", regex=True, inplace=True)
df['12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?'].replace("3-4 days", "3", regex=True, inplace=True)
df['12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?'].replace("5-6 days", "5", regex=True, inplace=True)
df['12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?'].replace("7 days", "7", regex=True, inplace=True)
df['12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 981    1
# 982    1
# 983    1
# 984    1
# 985    0
# Name: 12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?, Length: 986, dtype: object

# %%
df[['12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?','11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?','10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?','9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?','8. In the last 7 days, how many days did you feel tired?','7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?']] = df[['12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?','11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?','10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?','9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?','8. In the last 7 days, how many days did you feel tired?','7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?']].apply(pd.to_numeric, errors='coerce')

# %%
df['Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer'] = df['Q6_In_the_last_7_days_how_many_days_did_you_do_sports_or_exercise_for_at_least_1_hour_in_total_This_includes_doing_any_activities_including_online_activities_or_playing_sports_where_your_heart_beat_faster_you_breathed_faster_and_you_felt_warmer'].apply(pd.to_numeric, errors='coerce')

# %%
type(df['12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?'][0])
# Out:
# numpy.int64

# %%
import string
df["25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)"] = df["25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)"].str.rstrip(string.digits)
df["25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)"]
# Out:
# 0      NaN
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
#       ...
# 981    Yes
# 982    Yes
# 983    Yes
# 984    Yes
# 985    Yes
# Name: 25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc), Length: 986, dtype: object

# %%
mode_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df["Are you still going to school?"] = pd.DataFrame(mode_imputer.fit_transform(df[["Are you still going to school?"]]))
df["Do you have any other children living in your house with you?"] = pd.DataFrame(mode_imputer.fit_transform(df[["Do you have any other children living in your house with you?"]]))
df["25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)"] = pd.DataFrame(mode_imputer.fit_transform(df[["25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)"]]))

# %%
mode_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df["25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)"] = pd.DataFrame(mode_imputer.fit_transform(df[["25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)"]]))

# %%
df.isnull().sum()
# Out:
# ID                                                                                                                                                                                                                                                      0
# Are you still going to school?                                                                                                                                                                                                                          0
# Do you have any other children living in your house with you?                                                                                                                                                                                           0
# ...

# %% [markdown]
# # Binning on Breakfast column, categorising into 3 categories as Sugary cereal, Healthy cereal and Cooked food

# %%
for i in range(1,986):
    if re.search('Healthy', df['1. What did you eat for breakfast YESTERDAY?'][i]):
        df['1. What did you eat for breakfast YESTERDAY?'][i] = 'Healthy Food'
    elif re.search('Sugary', df['1. What did you eat for breakfast YESTERDAY?'][i]):
        df['1. What did you eat for breakfast YESTERDAY?'][i] = 'Sugary Food'
    elif re.search('Toast', df['1. What did you eat for breakfast YESTERDAY?'][i]):
        df['1. What did you eat for breakfast YESTERDAY?'][i] = 'Toast Food'
    elif re.search('Cooked', df['1. What did you eat for breakfast YESTERDAY?'][i]):
        df['1. What did you eat for breakfast YESTERDAY?'][i] = 'Cooked Food'
    elif re.search('Nothing', df['1. What did you eat for breakfast YESTERDAY?'][i]):
        df['1. What did you eat for breakfast YESTERDAY?'][i] = 'Nothing'
    else:
        df['1. What did you eat for breakfast YESTERDAY?'][i] = 'Other Food'
# Out:
# C:\Users\SYEDSH~1\AppData\Local\Temp/ipykernel_10952/2381559282.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['1. What did you eat for breakfast YESTERDAY?'][i] = 'Healthy Food'
# C:\Users\SYEDSH~1\AppData\Local\Temp/ipykernel_10952/2381559282.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['1. What did you eat for breakfast YESTERDAY?'][i] = 'Other Food'
# C:\Users\SYEDSH~1\AppData\Local\Temp/ipykernel_10952/2381559282.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['1. What did you eat for breakfast YESTERDAY?']
# Out:
# 0             Toast
# 1      Healthy Food
# 2        Other Food
# 3        Toast Food
# 4      Healthy Food
#            ...
# 981      Toast Food
# 982    Healthy Food
# 983      Other Food
# 984      Toast Food
# 985     Sugary Food
# Name: 1. What did you eat for breakfast YESTERDAY?, Length: 986, dtype: object

# %% [markdown]
# # A dataframe with all the Q24 columns

# %%
beh = df.iloc[:,-19:-3]
beh
# Out:
#     24. Remember, there are no right or wrong answers, just pick which is right for you. [I feel lonely]  \
# 0                                                Never
# 1                                            Sometimes
# 2                                                Never
# 3                                                Never
# 4                                                Never
# ..                                                 ...
# 981                                          Sometimes
# 982                                          Sometimes
# 983                                          Sometimes
# 984                                              Never
# 985                                              Never
#
#     24. Remember, there are no right or wrong answers, just pick which is right for you. [I cry a lot]  \
# 0                                                Never
# 1                                            Sometimes
# ...

# %% [markdown]
# # A dataframe containing all the emotional difficulties columns

# %%
Emo_difficulty_scale = df.iloc[:,-19:-9] 
Emo_difficulty_scale
# Out:
#     24. Remember, there are no right or wrong answers, just pick which is right for you. [I feel lonely]  \
# 0                                                Never
# 1                                            Sometimes
# 2                                                Never
# 3                                                Never
# 4                                                Never
# ..                                                 ...
# 981                                          Sometimes
# 982                                          Sometimes
# 983                                          Sometimes
# 984                                              Never
# 985                                              Never
#
#     24. Remember, there are no right or wrong answers, just pick which is right for you. [I cry a lot]  \
# 0                                                Never
# 1                                            Sometimes
# ...

# %% [markdown]
# # Label encoding the Q19 column (19. What type of places do you play in?)

# %%
Q19_label_encoded_DF = pd.DataFrame()
type(Q19_label_encoded_DF)
# Out:
# pandas.core.frame.DataFrame

# %%
place = ['In my house']
place1 = [' my garden']
place2 = ['a local grassy area']
place3 = ['football field']
place4 = ['with bushes, trees and flowers']
place5 = ['bike or skate park']
def converting_to_numerical(x):
    for i in place:
        if i.lower() in x.lower():
            return 1
        else:
            return 0
Q19_label_encoded_DF['Q19_label_encoded'] = df['19. What type of places do you play in?'].apply(converting_to_numerical)

def converting_to_numerical2(x):
    for i in place1:
        if i.lower() in x.lower():
            return 2
        else:
            return 0
Q19_label_encoded_DF['Q19_label_encoded2'] = df['19. What type of places do you play in?'].apply(converting_to_numerical2)

def converting_to_numerical3(x):
    for i in place2:
        if i.lower() in x.lower():
            return 3
        else:
            return 0
Q19_label_encoded_DF['Q19_label_encoded3'] = df['19. What type of places do you play in?'].apply(converting_to_numerical3)

def converting_to_numerical4(x):
    for i in place3:
        if i.lower() in x.lower():
            return 4
        else:
            return 0
Q19_label_encoded_DF['Q19_label_encoded4'] = df['19. What type of places do you play in?'].apply(converting_to_numerical4)

def converting_to_numerical5(x):
    for i in place4:
        if i.lower() in x.lower():
            return 5
        else:
            return 0
Q19_label_encoded_DF['Q19_label_encoded5'] = df['19. What type of places do you play in?'].apply(converting_to_numerical5)

def converting_to_numerical6(x):
    for i in place5:
        if i.lower() in x.lower():
            return 6
        else:
            return 0
Q19_label_encoded_DF['Q19_label_encoded6'] = df['19. What type of places do you play in?'].apply(converting_to_numerical6)

# %%
Q19_label_encoded_DF
# Out:
#      Q19_label_encoded  Q19_label_encoded2  Q19_label_encoded3  \
# 0                    1                   2                   0
# 1                    1                   2                   0
# 2                    1                   0                   0
# 3                    1                   2                   0
# 4                    1                   2                   0
# ..                 ...                 ...                 ...
# 981                  1                   2                   0
# 982                  1                   2                   3
# 983                  1                   2                   3
# 984                  1                   2                   3
# 985                  1                   2                   3
#
#      Q19_label_encoded4  Q19_label_encoded5  Q19_label_encoded6
# 0                     0                   0                   0
# 1                     0                   0                   0
# ...

# %% [markdown]
# # Taking some of all the label encoded values due to multiple options selected by the students

# %%
df["Q19_sum_of_places_child_plays"] = Q19_label_encoded_DF.sum(axis=1)
df["Q19_sum_of_places_child_plays"]
# Out:
# 0       3
# 1       3
# 2       1
# 3       3
# 4       8
#        ..
# 981     3
# 982    15
# 983    11
# 984    10
# 985    10
# Name: Q19_sum_of_places_child_plays, Length: 986, dtype: int64

# %%
sns.histplot(df.Q19_sum_of_places_child_plays)
# Out:
# <AxesSubplot:xlabel='Q19_sum_of_places_child_plays', ylabel='Count'>

# %% [markdown]
# # Label encoding the Q19 column (27. If yes, how are you keeping in touch (tick all you use)?)

# %%
Q27_label_encoded_DF = pd.DataFrame()
type(Q27_label_encoded_DF)
# Out:
# pandas.core.frame.DataFrame

# %%
touch1 = ['I live near them']
touch2 = ['By phone']
touch3 = ['On games consoles']
def converting_to_numerical(x):
    for i in touch1:
        if i.lower() in x.lower():
            return 1
        else:
            return 0
Q27_label_encoded_DF['Q27_label_encoded'] = df['27. If yes, how are you keeping in touch (tick all you use)?'].apply(converting_to_numerical)

def converting_to_numerical2(x):
    for i in touch2:
        if i.lower() in x.lower():
            return 2
        else:
            return 0
Q27_label_encoded_DF['Q27_label_encoded2'] = df['27. If yes, how are you keeping in touch (tick all you use)?'].apply(converting_to_numerical2)

def converting_to_numerical3(x):
    for i in touch3:
        if i.lower() in x.lower():
            return 3
        else:
            return 0
Q27_label_encoded_DF['Q27_label_encoded3'] = df['27. If yes, how are you keeping in touch (tick all you use)?'].apply(converting_to_numerical3)

# %%
Q27_label_encoded_DF
# Out:
#      Q27_label_encoded  Q27_label_encoded2  Q27_label_encoded3
# 0                    0                   2                   0
# 1                    0                   2                   0
# 2                    0                   2                   0
# 3                    1                   2                   0
# 4                    0                   2                   0
# ..                 ...                 ...                 ...
# 981                  0                   2                   0
# 982                  0                   2                   3
# 983                  1                   2                   0
# 984                  0                   2                   0
# 985                  1                   0                   3
#
# [986 rows x 3 columns]

# %% [markdown]
# # Taking some of all the label encoded values due to multiple options selected by the students

# %%
df['Q27_sum_of_child_keeping_in_touch'] = Q27_label_encoded_DF.sum(axis=1)
df['Q27_sum_of_child_keeping_in_touch']
# Out:
# 0      2
# 1      2
# 2      2
# 3      3
# 4      2
#       ..
# 981    2
# 982    5
# 983    3
# 984    2
# 985    4
# Name: Q27_sum_of_child_keeping_in_touch, Length: 986, dtype: int64

# %%
import datetime

# %% [markdown]
# # Finding how much hours childrens are sleeping

# %%
df.rename(columns={"4. What time did you fall asleep YESTERDAY (to the nearest half hour)?":"Q4_What_time_did_you_fall_asleep_YESTERDAY_to_the_nearest_half_hour","5. What time did you wake up TODAY (to the nearest half hour)?":"Q5_What_time_did_you_wake_up_TODAY_to_the_nearest_half_hour"},inplace=True)

# %%
df['Q4_What_time_did_you_fall_asleep_YESTERDAY_to_the_nearest_half_hour'] = pd.to_datetime(df.Q4_What_time_did_you_fall_asleep_YESTERDAY_to_the_nearest_half_hour)
df['Q4_What_time_did_you_fall_asleep_YESTERDAY_to_the_nearest_half_hour']

df['Q5_What_time_did_you_wake_up_TODAY_to_the_nearest_half_hour'] = pd.to_datetime(df.Q5_What_time_did_you_wake_up_TODAY_to_the_nearest_half_hour)
df['Q5_What_time_did_you_wake_up_TODAY_to_the_nearest_half_hour']
# Out:
# 0     2022-03-26 06:00:00
# 1     2022-03-26 09:00:00
# 2     2022-03-26 06:00:00
# 3     2022-03-26 08:00:00
# 4     2022-03-26 06:00:00
#               ...
# 981   2022-03-26 09:00:00
# 982   2022-03-26 08:00:00
# 983   2022-03-26 07:00:00
# 984   2022-03-26 07:00:00
# 985   2022-03-26 09:00:00
# Name: Q5_What_time_did_you_wake_up_TODAY_to_the_nearest_half_hour, Length: 986, dtype: datetime64[ns]

# %%
sleeping_hours = ((df['Q5_What_time_did_you_wake_up_TODAY_to_the_nearest_half_hour']) - (df['Q4_What_time_did_you_fall_asleep_YESTERDAY_to_the_nearest_half_hour']))
sleeping_hours
# Out:
# 0     -1 days +08:30:00
# 1     -1 days +10:00:00
# 2     -1 days +08:00:00
# 3     -1 days +12:00:00
# 4     -1 days +11:00:00
#              ...
# 981   -1 days +11:00:00
# 982     0 days 08:00:00
# 983   -1 days +11:30:00
# 984   -1 days +09:00:00
# 985   -1 days +10:30:00
# Length: 986, dtype: timedelta64[ns]

# %%
sleeping_hours.dt.components

sleeping_hours = pd.DataFrame(sleeping_hours.dt.components.hours)

# %%
sleeping_hours
df['sleeping_hours'] = sleeping_hours

# %%
df['sleeping_hours']
# Out:
# 0       8
# 1      10
# 2       8
# 3      12
# 4      11
#        ..
# 981    11
# 982     8
# 983    11
# 984     9
# 985    10
# Name: sleeping_hours, Length: 986, dtype: int64

# %%
df = df.drop(['Q4_What_time_did_you_fall_asleep_YESTERDAY_to_the_nearest_half_hour','Q5_What_time_did_you_wake_up_TODAY_to_the_nearest_half_hour'],axis=1)

# %%
df['What year are you in now?'] = df['What year are you in now?'].map({'Year 5':5,'Year 4':4,'Year 6':6,'Year 3':3})
df['What year are you in now?'].unique()
# Out:
# array([5, 4, 6, 3], dtype=int64)

# %%
# replcing Prefer not to say with mode
df['Gender'] = df['Gender'].replace(['Prefer not to say'],'Girl')
df['Gender'].value_counts()
# Out:
# Girl    499
# Boy     487
# Name: Gender, dtype: int64

# %% [markdown]
# # Dropping the columns which are not affecting the child wellbeing

# %%
df.drop(['ID','Year','Month','Day'],axis=1, inplace=True)

# %% [markdown]
# # Label Encoding ccolumns

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
df['Are you still going to school?']= labelencoder.fit_transform(df['Are you still going to school?'])
df['Do you have any other children living in your house with you?']= labelencoder.fit_transform(df['Do you have any other children living in your house with you?'])
df['1. What did you eat for breakfast YESTERDAY?']= labelencoder.fit_transform(df['1. What did you eat for breakfast YESTERDAY?'])
df['14. From your house, can you easily walk to a park (for example a field or grassy area)?']= labelencoder.fit_transform(df['14. From your house, can you easily walk to a park (for example a field or grassy area)?'])
df['15. From your house, can you easily walk to somewhere you can play?']= labelencoder.fit_transform(df['15. From your house, can you easily walk to somewhere you can play?'])
df['Gender']= labelencoder.fit_transform(df['Gender'])

# %%
df['Q16_Do_you_have_a_garden']= labelencoder.fit_transform(df['Q16_Do_you_have_a_garden'])
df['17. How often do you go out to play outside?']= labelencoder.fit_transform(df['17. How often do you go out to play outside?'])
df['18. Do you have enough time for play?']= labelencoder.fit_transform(df['18. Do you have enough time for play?'])
df['19. What type of places do you play in?']= labelencoder.fit_transform(df['19. What type of places do you play in?'])

# %%
df['20. Can you play in all the places you would like to?']= labelencoder.fit_transform(df['20. Can you play in all the places you would like to?'])
df['21. Do you have somewhere at home where you have space to relax?']= labelencoder.fit_transform(df['21. Do you have somewhere at home where you have space to relax?'])
df['22. Tell us if you agree or disagree with the following: [I am doing well with my school work]']= labelencoder.fit_transform(df['22. Tell us if you agree or disagree with the following: [I am doing well with my school work]'])
df['22. Tell us if you agree or disagree with the following: [I feel part of my school community]']= labelencoder.fit_transform(df['22. Tell us if you agree or disagree with the following: [I feel part of my school community]'])

# %% [markdown]
# # A dataframe containing all the Behavoural difficulties columns

# %%
Behaviour_difficulty_scale = df.iloc[:,-12:-6] 
Behaviour_difficulty_scale
# Out:
#     24. Remember, there are no right or wrong answers, just pick which is right for you. [I get very angry]  \
# 0                                                Never
# 1                                                Never
# 2                                                Never
# 3                                                Never
# 4                                                Never
# ..                                                 ...
# 981                                              Never
# 982                                          Sometimes
# 983                                          Sometimes
# 984                                              Never
# 985                                              Never
#
#     24. Remember, there are no right or wrong answers, just pick which is right for you. [I lose my temper]  \
# 0                                                Never
# 1                                                Never
# ...

# %%
df.rename(columns={"What year are you in now?":"What_year_are_you_in_now"},inplace=True)

# %% [markdown]
# # Label encoding behavioural difficulties columns

# %%
for column in Behaviour_difficulty_scale:
    encod = {'Never':0,'Sometimes':1,'Always':2}
    encod_reverse = {'Always':0,'Sometimes':1,'Never':2}
    if column == '24. Remember, there are no right or wrong answers, just pick which is right for you. [I am calm]':
        Behaviour_difficulty_scale[column] = Behaviour_difficulty_scale[column].map(encod_reverse)
    else:
        Behaviour_difficulty_scale[column] = Behaviour_difficulty_scale[column].map(encod)
Behaviour_difficulty_scale
# Out:
#      24. Remember, there are no right or wrong answers, just pick which is right for you. [I get very angry]  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 981                                                  0
# 982                                                  1
# 983                                                  1
# 984                                                  0
# 985                                                  0
#
#      24. Remember, there are no right or wrong answers, just pick which is right for you. [I lose my temper]  \
# 0                                                    0
# 1                                                    0
# ...

# %%
for column in beh:
    encod = {'Never':0,'Sometimes':1,'Always':2}
    encod_reverse = {'Always':0,'Sometimes':1,'Never':2}
    if column == '24. Remember, there are no right or wrong answers, just pick which is right for you. [I am calm]':
        beh[column] = beh[column].map(encod_reverse)
    else:
        beh[column] = beh[column].map(encod)
beh
# Out:
#      24. Remember, there are no right or wrong answers, just pick which is right for you. [I feel lonely]  \
# 0                                                    0
# 1                                                    1
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 981                                                  1
# 982                                                  1
# 983                                                  1
# 984                                                  0
# 985                                                  0
#
#      24. Remember, there are no right or wrong answers, just pick which is right for you. [I cry a lot]  \
# 0                                                    0
# 1                                                    1
# ...

# %% [markdown]
# # Label encoding Emotional difficulties columns

# %%
for column in Emo_difficulty_scale:
    encod = {'Never':0,'Sometimes':1,'Always':2}
    Emo_difficulty_scale[column] = Emo_difficulty_scale[column].map(encod)
Emo_difficulty_scale
# Out:
#      24. Remember, there are no right or wrong answers, just pick which is right for you. [I feel lonely]  \
# 0                                                    0
# 1                                                    1
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ..                                                 ...
# 981                                                  1
# 982                                                  1
# 983                                                  1
# 984                                                  0
# 985                                                  0
#
#      24. Remember, there are no right or wrong answers, just pick which is right for you. [I cry a lot]  \
# 0                                                    0
# 1                                                    1
# ...

# %%
df['22. Tell us if you agree or disagree with the following: [I have lots of choice over things that are important to me]']= labelencoder.fit_transform(df['22. Tell us if you agree or disagree with the following: [I have lots of choice over things that are important to me]'])
df["22. Tell us if you agree or disagree with the following: [There are lots of things I'm good at]"]= labelencoder.fit_transform(df["22. Tell us if you agree or disagree with the following: [There are lots of things I'm good at]"])

# %%
df["25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)"]= labelencoder.fit_transform(df["25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)"])
df['Q26_Are_you_able_to_keep_in_touch_with_your_friends']= labelencoder.fit_transform(df['Q26_Are_you_able_to_keep_in_touch_with_your_friends'])

# %%
df["27. If yes, how are you keeping in touch (tick all you use)?"]= labelencoder.fit_transform(df["27. If yes, how are you keeping in touch (tick all you use)?"])

# %%
df["27. If yes, how are you keeping in touch (tick all you use)?"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      5
# 4      0
#       ..
# 981    0
# 982    3
# 983    5
# 984    0
# 985    9
# Name: 27. If yes, how are you keeping in touch (tick all you use)?, Length: 986, dtype: int32

# %%
df["2. Did you eat any fruit and vegetables YESTERDAY? "][2:] = df["2. Did you eat any fruit and vegetables YESTERDAY? "][2:].str.replace(r'\D', '')
df["2. Did you eat any fruit and vegetables YESTERDAY? "].isnull().sum()
# Out:
# C:\Users\SYEDSH~1\AppData\Local\Temp/ipykernel_9152/4070891728.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["2. Did you eat any fruit and vegetables YESTERDAY? "][2:] = df["2. Did you eat any fruit and vegetables YESTERDAY? "][2:].str.replace(r'\D', '')
# C:\Users\SYEDSH~1\AppData\Local\Temp/ipykernel_9152/4070891728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["2. Did you eat any fruit and vegetables YESTERDAY? "][2:] = df["2. Did you eat any fruit and vegetables YESTERDAY? "][2:].str.replace(r'\D', '')
# 0

# %%
df["2. Did you eat any fruit and vegetables YESTERDAY? "] = df["2. Did you eat any fruit and vegetables YESTERDAY? "].apply(pd.to_numeric, errors='coerce')
type(df["2. Did you eat any fruit and vegetables YESTERDAY? "][0])
# Out:
# numpy.float64

# %%
df["2. Did you eat any fruit and vegetables YESTERDAY? "]  = pd.DataFrame(mode_imputer.fit_transform(df[["2. Did you eat any fruit and vegetables YESTERDAY? "]]))

# %%
df
# Out:
#      Are you still going to school?  \
# 0                                 1
# 1                                 1
# 2                                 1
# 3                                 1
# 4                                 1
# ..                              ...
# 981                               1
# 982                               1
# 983                               1
# 984                               1
# 985                               1
#
#      Do you have any other children living in your house with you?  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 981                                                  1
# 982                                                  1
# ...

# %% [markdown]
# # Renaming columns

# %%
df.rename(columns={'7. In the last 7 days, how many days did you watch TV/play online games/use the internet etc. for 2 or more hours a day (in total)?': 'Q7In_the_last_7_days_how_many_days_did_you_watch_TV_play_online_games_use_the_internet_etc_for_2_or_more_hours_a_day_in_total',
'9. In the last 7 days, how many days did you feel like you could concentrate/pay attention well on your school work?': 'Q9_In_the_last_7_days_how_many_days_did_you_feel_like_you_could_concentrate_pay_attention_well_on_your_school_work',
'1. What did you eat for breakfast YESTERDAY?':'Q1_What_did_you_eat_for_breakfast_YESTERDAY',
'2. Did you eat any fruit and vegetables YESTERDAY? ':'Q2_Did_you_eat_any_fruit_and_vegetables_YESTERDAY',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I feel lonely]':'Q24_I_feel_lonely',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I cry a lot]':'Q24_I_cry_a_lot',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I am unhappy]':'Q24_I_am_unhappy',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I feel nobody likes me]':'Q24_I_feel_nobody_likes_me',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I worry a lot]':'Q24_I_worry_a_lot',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I have problems sleeping]':'Q24_I_have_problems_sleeping',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I wake up in the night]':'Q24_I_wake_up_in_the_night',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I am shy]':'Q24_I_am_shy',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I feel scared]':'Q24_I_feel_scared',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I worry when I am at school]':'Q24_I_worry_when_I_am_at_school',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I get very angry]':'Q24_I_get_very_angry',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I lose my temper]':'Q24_I_lose_my_temper',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I hit out when I am angry]':'Q24_I_hit_out_when_I_am_angry',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I do things to hurt people]':'Q24_I_do_things_to_hurt_people',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I am calm]':'Q24_I_am_calm',
'24. Remember, there are no right or wrong answers, just pick which is right for you. [I break things on purpose]':'Q24_I_break_things_on_purpose',
"8. In the last 7 days, how many days did you feel tired?":"Q8_In_the_last_7_days_how_many_days_did_you_feel_tired",
"10. In the last 7 days, how many days did you drink at least one fizzy drink (e.g. coke, sprite, thumsup)?":"Q10_In_the_last_7days_how_many_days_did_you_drink_at_least_one_fizzy_drink__coke_sprite_thumsup",
"11. In the last 7 days, how many days did you eat at least one sugary snack (e.g. chocolate bar, sweets)?":"Q11_In_the_last_7days_how_many_days_did_you_eat_at_least_one_sugary_snack_chocolate_bar_sweets",
"12. In the last 7 days, how many days did you eat take away foods (e.g. Chinese takeaway)?":"Q12_In_the_last_7days_how_many_days_did_you_eat_take_away_foods_Chinese_takeaway",
"13. On a scale of 0 to 10 (0 being not very safe and 10 being very safe), how safe do you feel playing in your area?":"Q13_On_a_scale_of_0_to_10_0_being_not_very_safe_and_10_being_very_safe_how_safe_do_you_feel_playing_in_your_area"
,"14. From your house, can you easily walk to a park (for example a field or grassy area)?":"Q14_From_your_house_can_you_easily_walk_to_a_park_for_example_a_field_or_grassy_area"
,"15. From your house, can you easily walk to somewhere you can play?":"Q15_From_your_house_can_you_easily_walk_to_somewhere_you_can_play"
,"17. How often do you go out to play outside?":"Q17_How_often_do_you_go_out_to_play_outside"
,"18. Do you have enough time for play?":"Q18_Do_you_have_enough_time_for_play"
,"19. What type of places do you play in?":"Q19_What_type_of_places_do_you_play_in"
,"20. Can you play in all the places you would like to?":"Q20_Can_you_play_in_all_the_places_you_would_like_to"
,"21. Do you have somewhere at home where you have space to relax?":"Q21_Do_you_have_somewhere_at_home_where_you_have_space_to_relax"
,"22. Tell us if you agree or disagree with the following: [I am doing well with my school work]":"Q22_I_am_doing_well_with_my_school_work"
,"22. Tell us if you agree or disagree with the following: [I feel part of my school community]":"Q22_I_feel_part_of_my_school_community"
,"22. Tell us if you agree or disagree with the following: [I have lots of choice over things that are important to me]":"Q22_I_have_lots_of_choice_over_things_that_are_important_to_me"
,"22. Tell us if you agree or disagree with the following: [There are lots of things I'm good at]":"Q22_There_are_lots_of_things_Im_good_at"
,"27. If yes, how are you keeping in touch (tick all you use)?":"Q27_If_yes_how_are_you_keeping_in_touch_tick_all_you_use"
}, inplace=True)
df.rename(columns={'Are you still going to school?':'Are_you_still_going_to_school','Do you have any other children living in your house with you?':'Do_you_have_any_other_children_living_in_your_house_with_you','How many people live in your home with you (including adults)?':'How_many_people_live_in_your_home_with_you_including_adults',"25. Are you able to keep in touch with your family that you don't live with? (grand parents, Uncle, Aunt, Cousins, etc)":'Q25_Are_you_able_to_keep_in_touch_with_your_family_that_you_dont_live_with_grand_parents_Uncle_Aunt_Cousins_etc'},inplace=True)

# %%
df['Q1_What_did_you_eat_for_breakfast_YESTERDAY']
# Out:
# 0      5
# 1      1
# 2      3
# 3      6
# 4      1
#       ..
# 981    6
# 982    1
# 983    3
# 984    6
# 985    4
# Name: Q1_What_did_you_eat_for_breakfast_YESTERDAY, Length: 986, dtype: int32

# %%
df.iloc[:,-22:-6]
# Out:
#     Q24_I_feel_lonely Q24_I_cry_a_lot Q24_I_am_unhappy  \
# 0               Never           Never        Sometimes
# 1           Sometimes       Sometimes            Never
# 2               Never           Never            Never
# 3               Never       Sometimes        Sometimes
# 4               Never           Never            Never
# ..                ...             ...              ...
# 981         Sometimes       Sometimes            Never
# 982         Sometimes       Sometimes        Sometimes
# 983         Sometimes           Never            Never
# 984             Never           Never        Sometimes
# 985             Never           Never            Never
#
#     Q24_I_feel_nobody_likes_me Q24_I_worry_a_lot Q24_I_have_problems_sleeping  \
# 0                        Never             Never                        Never
# 1                        Never         Sometimes                       Always
# ...

# %% [markdown]
# # The total score is calculated by adding all the 16 items in the scale.

# %% [markdown]
# ## Total score of Emotional_Difficulties 10 columns

# %%
df['Emotional_Difficulties_Subscale']= Emo_difficulty_scale.sum(axis=1)
print(df['Emotional_Difficulties_Subscale'])
# Out:
# 0       3
# 1       8
# 2       1
# 3       4
# 4       1
#        ..
# 981    11
# 982    10
# 983     3
# 984     3
# 985     1
# Name: Emotional_Difficulties_Subscale, Length: 986, dtype: int64

# %% [markdown]
# ## Total score of Behavioural Difficulties 6 columns

# %%
df['Behavioural_Difficulties_Subscale']= Behaviour_difficulty_scale.sum(axis=1)
print(df['Behavioural_Difficulties_Subscale'])
# Out:
# 0      1
# 1      2
# 2      2
# 3      1
# 4      0
#       ..
# 981    1
# 982    6
# 983    1
# 984    0
# 985    0
# Name: Behavioural_Difficulties_Subscale, Length: 986, dtype: int64

# %% [markdown]
# # Type casting as Expected, Borderline_Difficultes and Significant_difficulties

# %%
bins = [-1,5,6,12]

# %%
df['Behavioural_Difficulties_Subscale'] = pd.cut(df['Behavioural_Difficulties_Subscale'],bins,labels=['Expected','Borderline_Difficultes','Significant_difficulties'] )
df['Behavioural_Difficulties_Subscale']
# Out:
# 0                    Expected
# 1                    Expected
# 2                    Expected
# 3                    Expected
# 4                    Expected
#                 ...
# 981                  Expected
# 982    Borderline_Difficultes
# 983                  Expected
# 984                  Expected
# 985                  Expected
# Name: Behavioural_Difficulties_Subscale, Length: 986, dtype: category
# Categories (3, object): ['Expected' < 'Borderline_Difficultes' < 'Significant_difficulties']

# %%
Behavioural_expected = df.loc[df['Behavioural_Difficulties_Subscale'] == 'Expected']
Behavioural_Borderline = df.loc[df['Behavioural_Difficulties_Subscale'] == 'Borderline_Difficultes']
Behavioural_Significant = df.loc[df['Behavioural_Difficulties_Subscale'] == 'Significant_difficulties']

# %% [markdown]
# # Type casting as Expected, Borderline_Difficultes and Significant_difficulties

# %%
df['Emotional_Difficulties_Subscale'] = pd.cut(df['Emotional_Difficulties_Subscale'],bins= [-1,9,11,12],labels=['Expected','Borderline_Difficultes','Significant_difficulties'] )
df['Emotional_Difficulties_Subscale']
# Out:
# 0                    Expected
# 1                    Expected
# 2                    Expected
# 3                    Expected
# 4                    Expected
#                 ...
# 981    Borderline_Difficultes
# 982    Borderline_Difficultes
# 983                  Expected
# 984                  Expected
# 985                  Expected
# Name: Emotional_Difficulties_Subscale, Length: 986, dtype: category
# Categories (3, object): ['Expected' < 'Borderline_Difficultes' < 'Significant_difficulties']

# %%
Emotional_expected = df.loc[df['Emotional_Difficulties_Subscale'] == 'Expected']
Emotional_Borderline = df.loc[df['Emotional_Difficulties_Subscale'] == 'Borderline_Difficultes']
Emotional_Significant = df.loc[df['Emotional_Difficulties_Subscale'] == 'Significant_difficulties']

# %%
mode_imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df[["Emotional_Difficulties_Subscale"]] = pd.DataFrame(mode_imputer.fit_transform(df[["Emotional_Difficulties_Subscale"]]))

# %% [markdown]
# # Dropping the columns with categorical data

# %%
df.drop(['Q27_If_yes_how_are_you_keeping_in_touch_tick_all_you_use',"Q19_What_type_of_places_do_you_play_in"],axis=1,inplace=True)

# %%
df.iloc[:,-23:-7]
# Out:
#     Q24_I_feel_lonely Q24_I_cry_a_lot Q24_I_am_unhappy  \
# 0               Never           Never        Sometimes
# 1           Sometimes       Sometimes            Never
# 2               Never           Never            Never
# 3               Never       Sometimes        Sometimes
# 4               Never           Never            Never
# ..                ...             ...              ...
# 981         Sometimes       Sometimes            Never
# 982         Sometimes       Sometimes        Sometimes
# 983         Sometimes           Never            Never
# 984             Never           Never        Sometimes
# 985             Never           Never            Never
#
#     Q24_I_feel_nobody_likes_me Q24_I_worry_a_lot Q24_I_have_problems_sleeping  \
# 0                        Never             Never                        Never
# 1                        Never         Sometimes                       Always
# ...

# %% [markdown]
# # Dropping all the Q24 columns with categorical data

# %%
df.drop(df.iloc[:,-23:-7],axis=1,inplace=True)

# %%
df
# Out:
#      Are_you_still_going_to_school  \
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 4                                1
# ..                             ...
# 981                              1
# 982                              1
# 983                              1
# 984                              1
# 985                              1
#
#      Do_you_have_any_other_children_living_in_your_house_with_you  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 981                                                  1
# 982                                                  1
# ...

# %% [markdown]
# # Making dataset_for_Behavioural_Difficulties_Subscale

# %%
dataset_for_Behavioural_Difficulties_Subscale = df.loc[:,df.columns!='Emotional_Difficulties_Subscale']
dataset_for_Behavioural_Difficulties_Subscale
# Out:
#      Are_you_still_going_to_school  \
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 4                                1
# ..                             ...
# 981                              1
# 982                              1
# 983                              1
# 984                              1
# 985                              1
#
#      Do_you_have_any_other_children_living_in_your_house_with_you  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 981                                                  1
# 982                                                  1
# ...

# %% [markdown]
# # Making dataset_for_Emotional_Difficulties_Subscale

# %%
dataset_for_Emotional_Difficulties_Subscale = df.loc[:,df.columns!='Behavioural_Difficulties_Subscale']
dataset_for_Emotional_Difficulties_Subscale
# Out:
#      Are_you_still_going_to_school  \
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 4                                1
# ..                             ...
# 981                              1
# 982                              1
# 983                              1
# 984                              1
# 985                              1
#
#      Do_you_have_any_other_children_living_in_your_house_with_you  \
# 0                                                    1
# 1                                                    1
# 2                                                    1
# 3                                                    1
# 4                                                    1
# ..                                                 ...
# 981                                                  1
# 982                                                  1
# ...
